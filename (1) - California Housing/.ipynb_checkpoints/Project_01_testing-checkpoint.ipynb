# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("data/housing.csv")

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
df.hist(figsize=(20,20))
plt.show()

# %%
df[df['latitude']<35].sort_values("latitude",ascending=False).mean()
# Out:
# longitude               -117.945511
# latitude                  33.838426
# housing_median_age        28.661707
# total_rooms             2709.596263
# total_bedrooms           564.678242
# population              1533.137354
# households               523.816419
# median_income              3.987807
# median_house_value    221314.126461
# dtype: float64

# %%
df[df['latitude']>35].sort_values("latitude",ascending=False).mean()
# Out:
# longitude               -121.532181
# latitude                  37.798856
# housing_median_age        28.610957
# total_rooms             2546.937941
# total_bedrooms           505.586952
# population              1295.592446
# households               470.279050
# median_income              3.729611
# median_house_value    189415.669270
# dtype: float64

# %%
def func(x):
    return x//1

# %%
df['new'] = df['latitude'].apply(func)

# %%
df.groupby("new").mean()
# Out:
#        longitude   latitude  housing_median_age  total_rooms  total_bedrooms  \
# new
# 32.0 -116.982580  32.763618           25.690840  2576.807634      537.890178
# 33.0 -117.868705  33.769961           27.074051  2736.881807      557.980873
# 34.0 -118.263742  34.177328           30.918972  2717.713284      577.863905
# 35.0 -119.354483  35.401264           24.584291  2740.678161      556.575000
# 36.0 -120.233735  36.622953           25.877095  2264.793296      460.868932
# 37.0 -121.923110  37.626489           32.508025  2536.215560      505.863861
# 38.0 -121.712632  38.446057           24.978866  2877.575889      552.923897
# 39.0 -121.709275  39.373845           23.569983  2139.870152      427.788494
# 40.0 -122.810030  40.558443           25.287425  2105.473054      427.591463
# 41.0 -122.784103  41.509744           25.051282  2515.666667      516.564103
#
#        population  households  median_income  median_house_value
# new
# ...

# %%
for i in df.columns:
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity', 'new'],
#       dtype='object')

# %%
df.groupby("new")['population'].plot()
# Out:
# new
# 32.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 33.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 34.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 35.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 36.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 37.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 38.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 39.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 40.0    AxesSubplot(0.125,0.125;0.775x0.755)
# 41.0    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: population, dtype: object

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000068D301C940>,
# ...
#       dtype=object)

# %%
plt.plot(df.latitude,df.population)

# %%
k=df.groupby('latitude').population.mean()
k.plot()
#plt.plot(df.latitude,df.groupby('latitude').population.mean())

# %%
from sklearn.model_selection import train_test_split

# %%
train,test = train_test_split(df,test_size=0.2,random_state=42)

# %%
df = train.copy()

# %%
len(df)
# Out:
# 16512

# %%
"""
last thing we did was to go through and split it into training data set and test data set
next thing to do is visualizng the data 

"""

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
x = df['population'].sort_values()

# %%
y = df.median_house_value[x.index]

# %%
x.head()
# Out:
# 5342     3.0
# 12458    5.0
# 3126     6.0
# 12286    8.0
# 18210    8.0
# Name: population, dtype: float64

# %%
y.head()
# Out:
# 5342     350000.0
# 12458    275000.0
# 3126     137500.0
# 12286     55000.0
# 18210    375000.0
# Name: median_house_value, dtype: float64

# %%
plt.hist(y)
# Out:
# (array([ 877., 3612., 4099., 3771., 2799., 1769., 1239.,  752.,  479.,
#         1243.]),
#  array([ 14999. ,  63499.2, 111999.4, 160499.6, 208999.8, 257500. ,
#         306000.2, 354500.4, 403000.6, 451500.8, 500001. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(df['median_house_value'])
# Out:
# (array([ 877., 3612., 4099., 3771., 2799., 1769., 1239.,  752.,  479.,
#         1243.]),
#  array([ 14999. ,  63499.2, 111999.4, 160499.6, 208999.8, 257500. ,
#         306000.2, 354500.4, 403000.6, 451500.8, 500001. ]),
#  <a list of 10 Patch objects>)

# %%
sns.jointplot(y,x)
# Out:
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# c:\users\dell\appdata\local\programs\python\python36\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
d = {'one':[1,2,3,4,5],'two':[10,20,30,40,50],'three':[100,200,300,400,500]}
df = pd.DataFrame(d)
df.head()
# Out:
#    one  two  three
# 0    1   10    100
# 1    2   20    200
# 2    3   30    300
# 3    4   40    400
# 4    5   50    500

# %%
df['one'].where(df['one']<3)
# Out:
# 0    1.0
# 1    2.0
# 2    NaN
# 3    NaN
# 4    NaN
# Name: one, dtype: float64

# %%
df
# Out:
#    one  two  three
# 0    1   10    100
# 1    2   20    200
# 2    5   30    300
# 3    5   40    400
# 4    5   50    500

# %%
df['one'].mask(df['one']<3,3,inplace=True)

# %%
df['one']
# Out:
# 0    3
# 1    3
# 2    3
# 3    4
# 4    5
# Name: one, dtype: int64
